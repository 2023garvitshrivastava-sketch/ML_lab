# %% [markdown]
# <a href="https://colab.research.google.com/github/2023garvitshrivastava-sketch/ML_lab/blob/main/Linear_Reg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.linear_model as LinearRegression

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("abhishek14398/salary-dataset-simple-linear-regression")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/salary-dataset-simple-linear-regression

# %%
df = pd.read_csv("Salary_dataset.csv")
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
YOE = df['YearsExperience']
Salary = df['Salary']
# Out:
# 0    1.2
# 1    1.4
# 2    1.6
# 3    2.1
# 4    2.3
# Name: YearsExperience, dtype: float64

# %%
model = LinearRegression.LinearRegression()
model.fit(YOE.values.reshape(-1,1),Salary)
# Out:
# LinearRegression()

# %%
intercept = model.intercept_
slope = model.coef_[0]

print(f"Intercept: {intercept}")
print(f"Slope: {slope}")
# Out:
# Intercept: 24848.203966523193
# Slope: [9449.96232146]

# %%
predicted_salary = model.predict(YOE.values.reshape(-1,1))
plt.scatter(YOE, Salary, color='blue', label='Actual Salary')
plt.plot(YOE, predicted_salary, color='red', label='Predicted Salary')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Salary vs Years of Experience')
plt.legend()
